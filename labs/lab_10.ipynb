# %% [markdown]
# # Lab 10
#
# _[General notebook information](https://computing-in-context.afeld.me/notebooks.html)_
#
# ## Objectives
#
# Practice:
#
# - Data cleaning
# - [Merging datasets through pandas](https://pandas.pydata.org/docs/user_guide/merging.html#merge)

# %% [markdown]
# ## Data Cleaning
#
# 1. Make messy data.
#    1. Open [this shared 311 data](https://docs.google.com/spreadsheets/d/1ZjDYeGqcoXz7AdHQ6N0q4zxMtEXp8JfLvjNFKN6kGtk/edit?gid=1427786321#gid=1427786321).
#    1. Make a couple edits to mess it up.
# 1. Download the data.
#    1. Click `File`.
#    1. Click `Download`.
#    1. Click `Comma Separated Values (.csv)`.
#
# Now this data is chaotic with some of your suggestions. How do we clean such a dataset?

# %% [markdown]
# ### Guide
#
# - Inspect the Data
# - Check missing values
# - Fix formatting issues and spaces
# - Standardize categoricals
# - Handle special characters
# - Handle bad [illogical] data

# %%
import pandas as pd
df = pd.read_csv("311 requests to make messy - 311 requests Nov 1-6, 2025.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40700 entries, 0 to 40699
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unique Key                      40700 non-null  int64
#  1   Created Date                    40700 non-null  object
#  2   Closed Date                     27418 non-null  object
#  3   Agency                          40700 non-null  object
#  4   Agency Name                     40700 non-null  object
#  5   Complaint Type                  40699 non-null  object
#  6   Descriptor                      39949 non-null  object
#  7   Location Type                   36715 non-null  object
#  8   Incident Zip                    40332 non-null  object
#  9   Incident Address                39706 non-null  object
#  10  Street Name                     39705 non-null  object
#  11  Cross Street 1                  28366 non-null  object
#  12  Cross Street 2                  28399 non-null  object
#  13  Intersection Street 1           26793 non-null  object
#  14  Intersection Street 2           26832 non-null  object
#  15  Address Type                    40527 non-null  object
#  16  City                            38995 non-null  object
#  17  Landmark                        24762 non-null  object
#  18  Facility Type                   53 non-null     object
#  19  Status                          40700 non-null  object
#  20  Due Date                        71 non-null     object
#  21  Resolution Description          34356 non-null  object
#  22  Resolution Action Updated Date  34730 non-null  object
#  23  Community Board                 40700 non-null  object
#  24  BBL                             37022 non-null  float64
#  25  Borough                         40699 non-null  object
#  26  X Coordinate (State Plane)      40288 non-null  object
#  27  Y Coordinate (State Plane)      40288 non-null  object
#  28  Open Data Channel Type          40700 non-null  object
#  29  Park Facility Name              40652 non-null  object
#  30  Park Borough                    40700 non-null  object
#  31  Vehicle Type                    1706 non-null   object
#  32  Taxi Company Borough            26 non-null     object
#  33  Taxi Pick Up Location           507 non-null    object
#  34  Bridge Highway Name             272 non-null    object
#  35  Bridge Highway Direction        126 non-null    object
#  36  Road Ramp                       94 non-null     object
#  37  Bridge Highway Segment          272 non-null    object
#  38  Latitude                        40288 non-null  float64
#  39  Longitude                       40288 non-null  float64
#  40  Location                        40288 non-null  object
# dtypes: float64(3), int64(1), object(37)
# memory usage: 12.7+ MB
# /var/folders/s3/lh26__4n17bdwjt4lwc8_1s40000gn/T/ipykernel_11189/3786942837.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("311 requests to make messy - 311 requests Nov 1-6, 2025.csv")

# %%
df.head()
df.describe()
# Out:
#          Unique Key           BBL      Latitude     Longitude
# count  4.070000e+04  3.702200e+04  40288.000000  40288.000000
# mean   6.670648e+07  2.697454e+09     40.734093    -73.924963
# std    1.262678e+04  1.166628e+09      0.083821      0.074002
# min    6.667357e+07  1.000030e+09     40.500925    -74.250974
# 25%    6.669583e+07  2.025363e+09     40.673330    -73.968759
# 50%    6.670638e+07  3.017955e+09     40.729329    -73.929105
# 75%    6.671736e+07  4.005230e+09     40.806334    -73.883598
# max    6.672824e+07  5.240010e+09     40.912869    -73.700928

# %%
df["Borough"].unique()
# Out:
# array(['QUEENS', 'BK', 'MANHATTAN', nan, 'BROOKLYN', 'STATEN ISLAND',
#        'BRONX', 'BROOKLYN ', 'BRONX ', 'QUEENS ', 'Unspecified'],
#       dtype=object)

# %%
df[df["Borough"] == "BK"]
# Out:
#    Unique Key            Created Date Closed Date Agency  \
# 2    66726589  11/05/2025 02:45:55 AM         NaN    DOT
#
#                     Agency Name    Complaint Type Descriptor Location Type  \
# 2  Department of Transportation  Street Condition    Pothole           NaN
#
#   Incident Zip Incident Address  ... Vehicle Type Taxi Company Borough  \
# 2        11229     KNAPP STREET  ...          NaN                  NaN
#
#   Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction  \
# 2                   NaN                 NaN                      NaN
#
#   Road Ramp Bridge Highway Segment Latitude Longitude Location
# 2       NaN                    NaN      NaN       NaN      NaN
#
# [1 rows x 41 columns]

# %%
df["Borough"] = df["Borough"].str.strip() # Remove leading/trailing whitespace
df["Borough"].unique()
# Out:
# array(['QUEENS', 'BK', 'MANHATTAN', nan, 'BROOKLYN', 'STATEN ISLAND',
#        'BRONX', 'Unspecified'], dtype=object)

# %%
df[df["Borough"].str.contains(".+\\s.+") == True]["Borough"]
# Out:
# 16       STATEN ISLAND
# 53       STATEN ISLAND
# 124      STATEN ISLAND
# 266      STATEN ISLAND
# 351      STATEN ISLAND
#              ...
# 40395    STATEN ISLAND
# 40445    STATEN ISLAND
# 40524    STATEN ISLAND
# 40670    STATEN ISLAND
# 40698    STATEN ISLAND
# Name: Borough, Length: 1392, dtype: object

# %%
df=df.replace("Qu eens ", "Queens")
df["Borough"].unique()

# %%
df = df.replace("BK", "Brooklyn")
df = df.replace("Unspecified", "nan")
df["Borough"].unique()
# Out:
# array(['QUEENS', 'Brooklyn', 'MANHATTAN', nan, 'BROOKLYN',
#        'STATEN ISLAND', 'BRONX', 'nan'], dtype=object)

# %%
df.dropna()
df = df[df["Borough"].notna()]
df["Borough"].unique()
# Out:
# array(['QUEENS', 'Brooklyn', 'MANHATTAN', 'BROOKLYN', 'STATEN ISLAND',
#        'BRONX', 'nan'], dtype=object)

# %%
df = df[df["Borough"]!="nan"] 
df["Borough"].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40672 entries, 0 to 40699
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unique Key                      40672 non-null  int64
#  1   Created Date                    40672 non-null  object
#  2   Closed Date                     27408 non-null  object
#  3   Agency                          40672 non-null  object
#  4   Agency Name                     40672 non-null  object
#  5   Complaint Type                  40671 non-null  object
#  6   Descriptor                      39921 non-null  object
#  7   Location Type                   36698 non-null  object
#  8   Incident Zip                    40330 non-null  object
#  9   Incident Address                39699 non-null  object
#  10  Street Name                     39698 non-null  object
#  11  Cross Street 1                  28360 non-null  object
#  12  Cross Street 2                  28393 non-null  object
#  13  Intersection Street 1           26785 non-null  object
#  14  Intersection Street 2           26824 non-null  object
#  15  Address Type                    40514 non-null  object
#  16  City                            38993 non-null  object
#  17  Landmark                        24760 non-null  object
#  18  Facility Type                   51 non-null     object
#  19  Status                          40672 non-null  object
#  20  Due Date                        71 non-null     object
#  21  Resolution Description          34346 non-null  object
#  22  Resolution Action Updated Date  34719 non-null  object
#  23  Community Board                 40672 non-null  object
#  24  BBL                             37021 non-null  float64
#  25  Borough                         40672 non-null  object
#  26  X Coordinate (State Plane)      40286 non-null  object
#  27  Y Coordinate (State Plane)      40286 non-null  object
#  28  Open Data Channel Type          40672 non-null  object
#  29  Park Facility Name              40624 non-null  object
#  30  Park Borough                    40672 non-null  object
#  31  Vehicle Type                    1703 non-null   object
#  32  Taxi Company Borough            25 non-null     object
#  33  Taxi Pick Up Location           507 non-null    object
#  34  Bridge Highway Name             272 non-null    object
#  35  Bridge Highway Direction        126 non-null    object
#  36  Road Ramp                       94 non-null     object
#  37  Bridge Highway Segment          272 non-null    object
#  38  Latitude                        40286 non-null  float64
#  39  Longitude                       40286 non-null  float64
#  40  Location                        40286 non-null  object
# dtypes: float64(3), int64(1), object(37)
# memory usage: 13.0+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40672 entries, 0 to 40699
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unique Key                      40672 non-null  int64
#  1   Created Date                    40672 non-null  object
#  2   Closed Date                     27408 non-null  object
#  3   Agency                          40672 non-null  object
#  4   Agency Name                     40672 non-null  object
#  5   Complaint Type                  40671 non-null  object
#  6   Descriptor                      39921 non-null  object
#  7   Location Type                   36698 non-null  object
#  8   Incident Zip                    40330 non-null  object
#  9   Incident Address                39699 non-null  object
#  10  Street Name                     39698 non-null  object
#  11  Cross Street 1                  28360 non-null  object
#  12  Cross Street 2                  28393 non-null  object
#  13  Intersection Street 1           26785 non-null  object
#  14  Intersection Street 2           26824 non-null  object
#  15  Address Type                    40514 non-null  object
#  16  City                            38993 non-null  object
#  17  Landmark                        24760 non-null  object
#  18  Facility Type                   51 non-null     object
#  19  Status                          40672 non-null  object
#  20  Due Date                        71 non-null     object
#  21  Resolution Description          34346 non-null  object
#  22  Resolution Action Updated Date  34719 non-null  object
#  23  Community Board                 40672 non-null  object
#  24  BBL                             37021 non-null  float64
#  25  Borough                         40672 non-null  object
#  26  X Coordinate (State Plane)      40286 non-null  object
#  27  Y Coordinate (State Plane)      40286 non-null  object
#  28  Open Data Channel Type          40672 non-null  object
#  29  Park Facility Name              40624 non-null  object
#  30  Park Borough                    40672 non-null  object
#  31  Vehicle Type                    1703 non-null   object
#  32  Taxi Company Borough            25 non-null     object
#  33  Taxi Pick Up Location           507 non-null    object
#  34  Bridge Highway Name             272 non-null    object
#  35  Bridge Highway Direction        126 non-null    object
#  36  Road Ramp                       94 non-null     object
#  37  Bridge Highway Segment          272 non-null    object
#  38  Latitude                        40286 non-null  float64
#  39  Longitude                       40286 non-null  float64
#  40  Location                        40286 non-null  object
# dtypes: float64(3), int64(1), object(37)
# memory usage: 13.0+ MB

# %% [markdown]
# ## Merging data
#
# Hint: The instructions here are intentionally incomplete.

# %% [markdown]
# ### Step 0
#
# Find an NYC dataset with a borough column.
#
# - Use [Scout](https://scout.tsdataclinic.com/explore/NYC) to filter by column name.
# - Don't spend too long on this step.
# - [Keep the dataset small](https://python-public-policy.afeld.me/en/columbia/assignments/open_ended.html#reducing-data-size) (under 500,000-ish rows) to make it easier to work with.

# %% [markdown]
# **What's the URL of your dataset?**

# %% [markdown]
# https://data.cityofnewyork.us/Education/2022-Annual-Sustainability-Project-Grant/uqtr-3rjs/about_data

# %% [markdown]
# ### Step 1
#
# Save and load the dataset.

# %%
import pandas as pd

df_sus = pd.read_csv("2022_Annual_Sustainability_Project_Grant_20251107.csv")
df_sus.head()
df_sus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   School Name     117 non-null    object
#  1   DBN             117 non-null    object
#  2   Borough         117 non-null    object
#  3   Grant Category  117 non-null    object
# dtypes: object(4)
# memory usage: 3.8+ KB

# %% [markdown]
# ### Step 2
#
# Download and load the [Population by Borough](https://data.cityofnewyork.us/City-Government/New-York-City-Population-by-Borough-1950-2040/xywu-7bv9) dataset.

# %%
import pandas as pd

df_population = pd.read_csv("New_York_City_Population_by_Borough,_1950_-_2040_20251107.csv")

df_population["Borough"] = df_population["Borough"].str.strip()

df_population = df_population[df_population["Borough"] != "NYC Total"]

print(df_population["Borough"].unique())
print(df_population.shape)
# Out:
# ['Bronx' 'Brooklyn' 'Manhattan' 'Queens' 'Staten Island']
# (5, 22)

# %% [markdown]
# ### Step 3
#
# Use [`merge()`](https://pandas.pydata.org/docs/user_guide/merging.html#merge) to combine the two, and output the resulting table.

# %%
df_sus_by_borough = df_sus.groupby("Borough").size().reset_index(name="num_grants")
print(df_sus_by_borough)

df = pd.merge(df_population, df_sus_by_borough, on="Borough")
df
# Out:
#          Borough  num_grants
# 0          Bronx          40
# 1       Brooklyn          42
# 2      Manhattan          21
# 3         Queens          12
# 4  Staten Island           2
#           Age Group        Borough       1950 1950 - Boro share of NYC total  \
# 0  Total Population          Bronx  1,451,277                         18.39%
# 1  Total Population       Brooklyn  2,738,175                          34.7%
# 2  Total Population      Manhattan  1,960,101                         24.84%
# 3  Total Population         Queens  1,550,849                         19.65%
# 4  Total Population  Staten Island    191,555                          2.43%
#
#         1960 1960 - Boro share of NYC total       1970  \
# 0  1,424,815                         18.31%  1,471,701
# 1  2,627,319                         33.76%  2,602,012
# 2  1,698,281                         21.82%  1,539,233
# 3  1,809,578                         23.25%  1,986,473
# 4    221,991                          2.85%    295,443
#
#   1970 - Boro share of NYC total       1980 1980 - Boro share of NYC total  \
# 0                         18.64%  1,168,972                         16.53%
# 1                         32.96%  2,230,936                         31.55%
# 2                          19.5%  1,428,285                          20.2%
# 3                         25.16%  1,891,325                         26.75%
# 4                          3.74%    352,121                          4.98%
#
#    ... 2000 - Boro share of NYC total       2010  \
# 0  ...                         16.64%  1,385,108
# 1  ...                         30.78%  2,552,911
# 2  ...                          19.2%  1,585,873
# 3  ...                         27.84%  2,250,002
# 4  ...                          5.54%    468,730
#
#   2010 - Boro share of NYC total       2020 2020 - Boro share of NYC total  \
# 0                          16.8%  1,446,788                         16.92%
# 1                         30.97%  2,648,452                         30.97%
# 2                         19.24%  1,638,281                         19.16%
# 3                          27.3%  2,330,295                         27.25%
# 4                          5.69%    487,155                           5.7%
#
#         2030 2030 - Boro share of NYC total       2040  \
# 0  1,518,998                         17.22%  1,579,245
# 1  2,754,009                         31.22%  2,840,525
# 2  1,676,720                         19.01%  1,691,617
# 3  2,373,551                         26.91%  2,412,649
# 4    497,749                          5.64%    501,109
#
#   2040 - Boro share of NYC total num_grants
# 0                          17.5%         40
# 1                         31.47%         42
# 2                         18.74%         21
# 3                         26.73%         12
# 4                          5.55%          2
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Step 4
#
# Using the two datasets above, use pandas to produce an aggregate per-capita statistic by borough.
#
# The dataset you chose before may not work for this. That's fine, pick another.
#
# #### Hint
#
# You're creating a "number of [thing] per capita by borough" table.
#
# 1. Do a [`groupby()`](https://pandas.pydata.org/docs/user_guide/groupby.html) on the original dataset.
# 1. Join with the populations by borough.
# 1. Compute the per-capita values as a new column.

# %%
df["population_2020"] = df["2020"].str.replace(",", "").astype(int)
df["grants_per_capita_2020"] = df["num_grants"] / df["population_2020"]
df[["Borough", "num_grants", "population_2020", "grants_per_capita_2020"]]
# Out:
#          Borough  num_grants  population_2020  grants_per_capita_2020
# 0          Bronx          40          1446788                0.000028
# 1       Brooklyn          42          2648452                0.000016
# 2      Manhattan          21          1638281                0.000013
# 3         Queens          12          2330295                0.000005
# 4  Staten Island           2           487155                0.000004

# %% [markdown]
# ### Step 5
#
# [Submit.](https://computing-in-context.afeld.me/notebooks.html#submission)
